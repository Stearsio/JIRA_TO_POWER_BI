# %%
notebook = '..\Main_Investigation\LoadAndSaveAllData.ipynb'
# %run $notebook

# %%
display(mainIssues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 display(mainIssues)
#
# NameError: name 'mainIssues' is not defined

# %%
display(customIssues)
# Out:
#              NaN InSight Error Category Covered in RAG
# 0     DWPPT-1820                   None           None  \
# 1     DWPPT-1819                   None           None
# 2     DWPPT-1818                   None           None
# 3     DWPPT-1817                   None           None
# 4     DWPPT-1816                   None           None
# ...          ...                    ...            ...
# 1187     DWPPT-8                   None           None
# 1188     DWPPT-7                   None           None
# 1189     DWPPT-6                   None           None
# 1190     DWPPT-4                   None           None
# 1191     DWPPT-3                   None           None
#
#      Requirement Stakeholders Functionality (Mustang) Value Stream Load Type
# 0                        None                    None         None      None  \
# 1                        None                    None         None      None
# ...

# %%
display(customFieldsAndId)
# Out:
#                field_id                field_name
# 0     customfield_17021          Idea archived on
# 1     customfield_15084                Res Entity
# 2     customfield_17020               Goal impact
# 3     customfield_15085              Res File Set
# 4     customfield_15082                      Link
# ...                 ...                       ...
# 1039  customfield_15535          Rejection Reason
# 1040  customfield_15529   CR Reference (LEAP CDM)
# 1041  customfield_15769            Benefit driver
# 1042  customfield_15527               DS Category
# 1043  customfield_15528  Alemba ticket (LEAP CDM)
#
# [1044 rows x 2 columns]
